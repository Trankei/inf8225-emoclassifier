# %%
from __future__ import print_function, division
import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms, utils
import requests
from bs4 import BeautifulSoup

# Ignore warnings
#import warnings
#warnings.filterwarnings("ignore")

plt.ion()   # interactive mode

# %%
# test pour une image
happy_data = pd.read_csv('reddit_data/processed_happy.csv')
img_url = happy_data.iloc[0, 2]
img_ups = happy_data.iloc[0, 3]
img_title = happy_data.iloc[0, 6]

print(img_url)
if 'imgur' in img_url:
    if '.jpeg' not in img_url :
        if '.jpg'not in img_url : 
            if '.png'not in img_url : 
                requete = requests.get(img_url)
                page = requete.content
                soup = BeautifulSoup(page)
                img_url = soup.find('link', rel="image_src", href=True)
                if (img_url): 
                    img_url = img_url['href']
        
print('Image url: {}'.format(img_url))
print('Image upvotes: {}'.format(img_ups))
print('Image description: {}'.format(img_title))
    
plt.figure()

try :
    plt.imshow(io.imread(img_url))
except :
      print("Requested photo not available.")
      
plt.show()
# Out:
# http://imgur.com/DPnilTa
# Image url: https://i.imgur.com/DPnilTa.jpg
# Image upvotes: 295
# Image description: It's the little things.

# %%
class RedditDataset(Dataset):
    """Reddit dataset."""

    def __init__(self, folder, transform=None):
        """
        Args:
            csv_file(string): Path to the csv file.
            transform (callable, optional): Optional transform to be applied on a sample.
        """
        happy_data = pd.read_csv(folder + '/processed_happy.csv')
        creepy_data = pd.read_csv(folder + '/processed_creepy.csv')
        gore_data = pd.read_csv(folder + '/processed_gore.csv')
        rage_data = pd.read_csv(folder +'/processed_rage.csv')
        self.reddit_data = (pd.concat([happy_data, creepy_data, gore_data,rage_data])).sort_values(by = 'ups', ascending=False)

        self.transform = transform

    def __len__(self):
        return len(self.reddit_data)

    def __getitem__(self, idx):
        
        img_url = self.reddit_data.iloc[idx, 2]
        print(img_url)
        if 'imgur' in img_url:
            if '.jpeg' not in img_url :
                if '.jpg'not in img_url : 
                    if '.png'not in img_url : 
                        requete = requests.get(img_url)
                        page = requete.content
                        soup = BeautifulSoup(page)
                        img_url = soup.find('link', rel="image_src", href=True)
                        if (img_url): 
                            img_url = img_url['href']
        #img_ups = self.reddit_data.iloc[idx, 3]
        img_title = self.reddit_data.iloc[idx, 6]
        img_label = self.reddit_data.iloc[idx, 8]
        
        try:
            image = io.imread(img_url)
            
        except:
            print("Requested photo not available.")
            sample = None
            # supprimer le sample
        else:
            sample = {'image': image,'description': img_title, 'label': img_label}
            
        if self.transform:
            sample = self.transform(sample)
            #sample['image'].transforms.Resize((229,229))
            #sample['image'].transforms.ToTensor()
            #print(sample['image'].shape())

        return sample

# %%
data_transform = transforms.Compose([
        #transforms.Resize((229,229)),# ajouter interpolation
        transforms.ToTensor()
   ])

#image = cv2.imread('test1.png',cv2.IMREAD_COLOR)
#image = img_to_array(image)
# reshape data for the model
#image = cv2.resize(image, (229, 229), interpolation = cv2.INTER_AREA)
#image = image.reshape((1, 229, 229, 3))
# prepare the image for the VGG model
#image = preprocess_input(image)

reddit_dataset = RedditDataset('reddit_data')
#print(len(reddit_dataset))

#fig = plt.figure()

#for i in range(len(reddit_dataset)):
#    sample = reddit_dataset[i]
#   if sample :
#        print(i, sample['image'].shape, sample['description'], sample['label'])

#    ax = plt.subplot(1, 4, i + 1)
#    plt.tight_layout()
#    ax.set_title('Sample #{}'.format(i))
#    ax.axis('off')
#    plt.imshow(sample['image'])

#    if i == 3:
#        plt.show()
#        break

# %%
train_loader = DataLoader(reddit_dataset, batch_size=4, shuffle=True, num_workers=4)

test_indices = list(range(0,int(len(reddit_dataset)*0.1)))
test_dataset = Subset(reddit_dataset, test_indices)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=True, num_workers=4)

validation_indices = list(range(int(len(reddit_dataset)*0.1), 2*int(len(reddit_dataset)*0.1)+1))
validation_dataset = Subset(reddit_dataset, validation_indices)
validation_loader = DataLoader(validation_dataset, batch_size=4, shuffle=True, num_workers=4)

#for i in range(len(test_dataset)):
#    sample = test_dataset[i]
#    if sample :
#        print(i, sample['image'].shape,t sample['upvotes'], sample['description'])
